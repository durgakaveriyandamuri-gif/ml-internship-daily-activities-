# %% [markdown]
# # Feature engineering
#         Feature engineering is the process of converting raw data into  meaningful numerical features so that a machine learning
#         model can understand patterns and make better predictions.
# ###        1. Feature exploration:
#         -------------------
#         The process of analyzing and visualizing features to uncover patterns, distributions, correlations and potential
#         issues in the dataset before applying machine learning.
# ###        2. Feature creation:
#         ---------------------
#         The process of generating new meaningful features from existing data using domain knowledge or mathematical
#         operrations to help the model learn better patterns.
# ###        3. Feature Encoding:
#         --------------------
#         The process of converting categorical or non- numeric features into numeric form so machine learning models can process
#         them effectively.
# ###        4. Feature Scaling:
#         -------------------
#         The  process of transforming numerical features to a standard range or distribution so that no feature dominates the
#         learning process due to its scale.
# ###        5. Feature Selection:
#         ------------------------
#         The processs of identifying and keeping only the most relevant features while removing irrelevant or redundant  ones to
#         improve model performance and reduce overfitting.
# # Feature Creation:(Adds intelligence)
# --------------------------------
#       Feature creation is the process of creating new features from existing data using domain knowledge and mathematical operations
#     to help the model learn  better patterns.
# ### Why it "Adds intelligence"?
#         > Raw data may not show hidden relationships
#         > New features probide extra information.
#         > Models cannot think logically- features guide learning
# ### Common types of feature creation:
#         > Domain based features( Real world logic)
#         > Mathematical combinations(Sum, average,ratio)
#         > Interactions features(combined effect of features)
#         > Polynomial features(non-linear relationships)
# ### Example:
# > Total marks=math+science
#
# > Efficiency=total marks/study hours
# ### Impact on model:
# > Improves accuracy
# > Hepls models capture complex patterns
# > Makes simple models perform better

# %% [markdown]
# # Feature creation

# %%
import pandas as pd
df=pd.DataFrame({
    "study_hours":[2,4,6,8,10],
    "attendance":[60,70,80,90,95],
    "maths":[40,55,65,75,80],
    "science":[42,58,68,78,88]
})
df
# Out:
#    study_hours  attendance  maths  science
# 0            2          60     40       42
# 1            4          70     55       58
# 2            6          80     65       68
# 3            8          90     75       78
# 4           10          95     80       88

# %% [markdown]
# # Domain based feature

# %%
df['total_marks']=df['maths']+df['science']
df
# Out:
#    study_hours  attendance  maths  science  total_marks
# 0            2          60     40       42           82
# 1            4          70     55       58          113
# 2            6          80     65       68          133
# 3            8          90     75       78          153
# 4           10          95     80       88          168

# %% [markdown]
# ## Mathemtical feature

# %%
df["marks_per_hour"]=df['total_marks']/df["study_hours"]
df
# Out:
#    study_hours  attendance  maths  science  total_marks  marks_per_hour
# 0            2          60     40       42           82       41.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000

# %% [markdown]
# ## Interaction feature

# %%
df['study_inetraction_attandance']=df["study_hours"]*df["attendance"]
df
# Out:
#    study_hours  attendance  maths  science  total_marks  marks_per_hour  \
# 0            2          60     40       42           82       41.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000
#
#    study_inetraction_attandance
# 0                           120
# 1                           280
# 2                           480
# 3                           720
# 4                           950

# %% [markdown]
# ## polynomial feature

# %%
df["study_hour_squared"]=df["study_hours"]**2

# %%
df
# Out:
#    study_hours  attendance  maths  science  total_marks  marks_per_hour  \
# 0            2          60     40       42           82       41.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000
#
#    study_inetraction_attandance  study_hour_squared
# 0                           120                   4
# 1                           280                  16
# 2                           480                  36
# 3                           720                  64
# 4                           950                 100

# %% [markdown]
# # Feature Selection:
#       Feature selection is the process of selecting only relevant features and removing irrelecant or redundant ones to improve
#     model performance.
# ### why it "remove noise":
#     > To many features confuse the model
#     > Irrelevant features cause overfitting
#     > Noise reduce prediction accuracy
# ### Types of feature  selecton:
#     > Filter methods( correlation,chi-square)
#     > Wrapper methods(forward,backward,RFE)
#     > embedded methods(Lasso,tree based models)
# ### example:
#     > removing weakly correlated features
#     > Dropping features with zero importance
#     > selecting top features using RFE( recursive feature elimination)
# ### Impact on model:
#     > Reduce overfitting
#     > Improves generalization
#     > Speeds up training

# %%
df
# Out:
#    study_hours  attendance  maths  science  total_marks  marks_per_hour  \
# 0            2          60     40       42           82       41.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000
#
#    study_inetraction_attandance  study_hour_squared
# 0                           120                   4
# 1                           280                  16
# 2                           480                  36
# 3                           720                  64
# 4                           950                 100

# %%
x=df.drop("science",axis=1) #drop  delets rows so axis deletes the columns
y=df["science"]

# %%
x
# Out:
#    study_hours  attendance  maths  total_marks  marks_per_hour  \
# 0            2          60     40           82       41.000000
# 1            4          70     55          113       28.250000
# 2            6          80     65          133       22.166667
# 3            8          90     75          153       19.125000
# 4           10          95     80          168       16.800000
#
#    study_inetraction_attandance  study_hour_squared
# 0                           120                   4
# 1                           280                  16
# 2                           480                  36
# 3                           720                  64
# 4                           950                 100

# %%
y
# Out:
# 0    42
# 1    58
# 2    68
# 3    78
# 4    88
# Name: science, dtype: int64

# %% [markdown]
# # filter methods (Statistics-Based)

# %% [markdown]
#  ## Correlation method

# %%
df.corr()["science"].sort_values(ascending=False)
# Out:
# science                         1.000000
# total_marks                     0.998981
# maths                           0.995467
# study_hours                     0.994309
# attendance                      0.994110
# study_inetraction_attandance    0.983804
# study_hour_squared              0.958102
# marks_per_hour                 -0.968737
# Name: science, dtype: float64

# %%
corr=df.corr()["science"].abs() # absolute

# %%
corr
# Out:
# study_hours                     0.994309
# attendance                      0.994110
# maths                           0.995467
# science                         1.000000
# total_marks                     0.998981
# marks_per_hour                  0.968737
# study_inetraction_attandance    0.983804
# study_hour_squared              0.958102
# Name: science, dtype: float64

# %%
selected_features=corr[corr>0.8].index
selected_features
# Out:
# Index(['study_hours', 'attendance', 'maths', 'science', 'total_marks',
#        'marks_per_hour', 'study_inetraction_attandance', 'study_hour_squared'],
#       dtype='object')
